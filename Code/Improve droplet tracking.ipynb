# %% [markdown]
# # Improve droplet tracking

# %% [markdown]
# ## 0 Create a test dataset
#
# I choose the video 11022021\03 as the test image, for its good image quality and relative simplicity for tracking. Frames 0-99, corresponding to 2 s in real time, are used. Noticeable motion is observed within this time window.
#
# The test images are stored in Documents\11022021\03 folder. A ground truth trajectory is generated by hand tracking and placed in the same folder, with file name as "hand-traj.csv".
#
# Let's start from a single frame, by carefully examine the image intensity profiles, and try to apply the radial symmetry idea to the test image.
